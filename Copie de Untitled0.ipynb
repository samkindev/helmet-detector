# %%
# !wget https://github.com/samkindev/datasets/raw/e49a22e11af0bdc83439abae0814bf57f8717d67/helmet_dataset.zip
# Out:
# --2023-10-14 14:48:09--  https://github.com/samkindev/datasets/raw/e49a22e11af0bdc83439abae0814bf57f8717d67/helmet_dataset.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/samkindev/datasets/e49a22e11af0bdc83439abae0814bf57f8717d67/helmet_dataset.zip [following]
# --2023-10-14 14:48:09--  https://raw.githubusercontent.com/samkindev/datasets/e49a22e11af0bdc83439abae0814bf57f8717d67/helmet_dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6326156 (6.0M) [application/zip]
# Saving to: ‘helmet_dataset.zip’
#
# ...

# %%
# !unzip helmet_dataset.zip

# %%
# !rm -r helmet_dataset.zip
# Out:
# rm: cannot remove 'helmet_dataset.zip': No such file or directory

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=/content/data.yaml epochs=50
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 233MB/s]
# Ultralytics YOLOv8.0.198 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
